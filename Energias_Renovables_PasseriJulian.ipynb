# %%
#Seccion 1: Importacion de librerias y un documento en un data frame: "df"
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("D:/Universidad/Python Project/Python Project Pandas/global-data-on-sustainable-energy .csv")

# %%
#Seccion 2: Seccion de Head, los primeros elementos
df.head()
# Out:
#         Entity    Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000.0                                 1.613591
# 1  Afghanistan  2001.0                                 4.074574
# 2  Afghanistan  2002.0                                 9.409158
# 3  Afghanistan  2003.0                                14.738506
# 4  Afghanistan  2004.0                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
# ...

# %%
#Seccion 3: Seccion del tail, ultimos elementos
df.tail()
# Out:
#         Entity    Year  Access to electricity (% of population)  \
# 3644  Zimbabwe  2016.0                                42.561730
# 3645  Zimbabwe  2017.0                                44.178635
# 3646  Zimbabwe  2018.0                                45.572647
# 3647  Zimbabwe  2019.0                                46.781475
# 3648  Zimbabwe  2020.0                                52.747670
#
#       Access to clean fuels for cooking  \
# 3644                               29.8
# 3645                               29.8
# 3646                               29.9
# 3647                               30.1
# 3648                               30.4
#
#       Renewable-electricity-generating-capacity-per-capita  \
# 3644                                              62.88
# 3645                                              62.33
# 3646                                              82.53
# 3647                                              81.40
# ...

# %%
#Seccion 4: Forma del documento
df.shape
# Out:
# (3649, 21)

# %%
#Seccion 5: Cantidad de elementos por columna
df.count()
# Out:
# Entity                                                              3649
# Year                                                                3544
# Access to electricity (% of population)                             3534
# Access to clean fuels for cooking                                   3375
# Renewable-electricity-generating-capacity-per-capita                2634
# Financial flows to developing countries (US $)                      1529
# Renewable energy share in the total final energy consumption (%)    3355
# Electricity from fossil fuels (TWh)                                 3523
# Electricity from nuclear (TWh)                                      3418
# Electricity from renewables (TWh)                                   3523
# Low-carbon electricity (% electricity)                              3502
# Primary energy consumption per capita (kWh/person)                  3544
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)         3342
# ...

# %%
#Seccion 6: Tipo de datos de cada columna
df.dtypes
# Out:
# Entity                                                               object
# Year                                                                float64
# Access to electricity (% of population)                             float64
# Access to clean fuels for cooking                                   float64
# Renewable-electricity-generating-capacity-per-capita                float64
# Financial flows to developing countries (US $)                      float64
# Renewable energy share in the total final energy consumption (%)    float64
# Electricity from fossil fuels (TWh)                                 float64
# Electricity from nuclear (TWh)                                      float64
# Electricity from renewables (TWh)                                   float64
# Low-carbon electricity (% electricity)                              float64
# Primary energy consumption per capita (kWh/person)                  float64
# ...

# %%
#Seccion 7: Tipo de CSV
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Seccion 8: Nombres de las columnas
print(df.columns)
# Out:
# Index(['Entity', 'Year', 'Access to electricity (% of population)',
#        'Access to clean fuels for cooking',
#        'Renewable-electricity-generating-capacity-per-capita',
#        'Financial flows to developing countries (US $)',
#        'Renewable energy share in the total final energy consumption (%)',
#        'Electricity from fossil fuels (TWh)', 'Electricity from nuclear (TWh)',
#        'Electricity from renewables (TWh)',
#        'Low-carbon electricity (% electricity)',
#        'Primary energy consumption per capita (kWh/person)',
#        'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
#        'Value_co2_emissions_kt_by_country',
#        'Renewables (% equivalent primary energy)', 'gdp_growth',
#        'gdp_per_capita', 'Density(P/Km2)', 'Land Area(Km2)', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
#Seccion 9: Elemino ciertas columnas para realizar un modelo predictivo, tambien limpio datos vacios para evitar NaN
df_cleaned = df.dropna(subset=['Value_co2_emissions_kt_by_country'])

X = df_cleaned.drop(columns=['Entity'], axis=1) #Axis indica columnas, hago un drop de Entity debido a errores de tipos de datos
y =df_cleaned.Value_co2_emissions_kt_by_country   #Defino el target de estudio, emisiones de CO2 por Pais

from sklearn.model_selection import train_test_split #Libereria para separar entre train y test 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
#Seccion 10: Elemino ciertas columnas para realizar un modelo predictivo 
#Implemento otro modelo, debido al tipo de datos manejados en CO2 (valores continuos)
from sklearn.tree import DecisionTreeRegressor 
# Lo entrenamos
tree_regressor = DecisionTreeRegressor()
tree_regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
#Seccion 11: Busco elementos vacios de datos
missing_values = y_train.isnull().sum()
print("Valores faltantes para entrenar en y_train:", missing_values)
# Out:
# Valores faltantes para entrenar en y_train: 0

# %%
#Seccion 12: Realizo las predicciones
y_pred = tree_regressor.predict(X_test)

# %%
#Seccion 13: Evaluamos al modelo
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

#Errores medios absolutos (MAE), errores medios cuadrados (MSE) y coeficiente de determinación (R2) en el contexto de la modelización de regresión:

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)


print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 17732.947567140684
# Mean Squared Error: 11797042468.031599
# R-squared: 0.9637806417802283

# %%
#Seccion 14: Creamos Grafica

metrics = ['MAE', 'MSE', 'R-squared']
values = [mae, mse, r2]
log_values = np.log10(values) #Aplico una escala logaritmica 

# Crear un gráfico de barras con valores escalados en escala logarítmicaplt.figure(figsize=(8, 5))
plt.bar(metrics, log_values, color=['blue', 'green', 'orange'])
plt.xlabel('Metrics')
plt.ylabel('Logarithm of Values (log10)')
plt.title('Logarithmic Scale Model Evaluation Metrics')

# Mostrar los valores reales en la parte superior de las barras
for i, v in enumerate(log_values):
    plt.text(i, v + 0.02, str(round(values[i], 2)), ha='center', va='bottom')

plt.show()
